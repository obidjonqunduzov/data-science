# %%
import numpy as np
import pandas as pd

# %%
df_2015 = pd.read_csv(r"C:\Users\obidjon\Downloads\happens\2015.csv") 
df_2016 = pd.read_csv(r"C:\Users\obidjon\Downloads\happens\2016.csv")
df_2017 = pd.read_csv(r"C:\Users\obidjon\Downloads\happens\2017.csv")
df_2018 = pd.read_csv(r"C:\Users\obidjon\Downloads\happens\2018.csv")
df_2019 = pd.read_csv(r"C:\Users\obidjon\Downloads\happens\2019.csv")
df_2020 = pd.read_csv(r"C:\Users\obidjon\Downloads\happens\2020.csv")
df_2021 = pd.read_csv(r"C:\Users\obidjon\Downloads\happens\2021.csv")

# hamma DataFrame larni yuklab olamiz

# %%
df_2015.head(3)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204

# %%
df_2016.head(3)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# 2                   1.42666  1.18326                   0.86733  0.56624
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# ...

# %%
df_2017.head(3)
# Out:
#    Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0   Norway               1            7.537      7.594445     7.479556
# 1  Denmark               2            7.522      7.581728     7.462272
# 2  Iceland               3            7.504      7.622030     7.385970
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027
# 1    0.355280                       0.400770           2.313707
# 2    0.475540                       0.153527           2.322715

# %%
df_2018.head(3)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# 2                      0.408

# %%
df_2019.head(3)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341

# %%
df_2020.head(3)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267        0.954330                71.900825
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                      0.949172   -0.059482                   0.195445
# 1                      0.951444    0.066202                   0.168489
# ...

# %%
df_2021.head(3)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.949      -0.098                      0.186
# 1                         0.946       0.030                      0.179
# ...

# %%
df_drop_2015 = df_2015.drop(['Standard Error',
                              'Economy (GDP per Capita)',
                              'Family',
                              'Health (Life Expectancy)',
                              'Freedom',
                              'Trust (Government Corruption)',
                              'Generosity',
                              'Dystopia Residual'], axis=1)
# DataFramedagi bizga zarur bo'lmagan ustunlarni tashlab yuboramiz

# %%
df_irarxik_2015 =  pd.pivot_table(df_drop_2015, index = ['Region','Country'],
                                  values = ['Happiness Rank','Happiness Score']) 
df_irarxik_2015.head(3)
# irarxik indeksli ma'lumotlar to'plamiga o'tish 2015 yilga tegishli ma'lumotlar uchun
# Out:
#                                         Happiness Rank  Happiness Score
# Region                     Country
# Australia and New Zealand  Australia              10.0            7.284
#                            New Zealand             9.0            7.286
# Central and Eastern Europe Albania                95.0            4.959

# %%
df_drop_2016 = df_2016.drop(['Lower Confidence Interval', 'Upper Confidence Interval',
       'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
       'Freedom', 'Trust (Government Corruption)', 'Generosity',
       'Dystopia Residual'], axis=1)
# DataFramedagi bizga zarur bo'lmagan ustunlarni tashlab yuboramiz

# %%
df_irarxik_2016 =  pd.pivot_table(df_drop_2016, index = ['Region','Country'],
                                  values = ['Happiness Rank','Happiness Score']) 
df_irarxik_2016.head(3)
# irarxik indeksli ma'lumotlar to'plamiga o'tish 2016 yilga tegishli ma'lumotlar uchun
# Out:
#                                         Happiness Rank  Happiness Score
# Region                     Country
# Australia and New Zealand  Australia               9.0            7.313
#                            New Zealand             8.0            7.334
# Central and Eastern Europe Albania               109.0            4.655

# %%
df_drop_2017 = df_2017.drop(['Whisker.high',
       'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
       'Health..Life.Expectancy.', 'Freedom', 'Generosity',
       'Trust..Government.Corruption.', 'Dystopia.Residual'],axis=1)
# DataFramedagi bizga zarur bo'lmagan ustunlarni tashlab yuboramiz

# %%
df_drop_2017.rename(columns={'Happiness.Rank':'Happiness Rank',
                             'Happiness.Score':'Happiness Score'}, inplace=True)
# Avvalo 2017 yildagi ustunlaridagi xatoni to'girladek

# %%
dfrc = df_2016[['Region','Country']] # 2016 yilgi iiki ustunni chaqirib oldek
dfc = df_2017[['Country']] # 2017 yilgi faqat mavjud Country ustunini chaqirib oldek
data = pd.merge(dfrc,dfc, how='right') # shu ikki dataset orasini bo'gladek
df_region = data['Region'] # va shu bo'glangan datasetdan Region ustunini oldek

# %%
df_irarxik_2017 =  pd.pivot_table(df_drop_2017, index = [df_region,'Country'],
                                  values = ['Happiness Rank','Happiness Score']) 
df_irarxik_2017.head(3)
# Avvalgi qismdagi Region ustunini shu datasetda mavjud bo'lmagan ustunlar ro'yxatiga qo'shdek
# irarxik indeksli ma'lumotlar to'plamiga o'tish 2017 yilga tegishli ma'lumotlar uchun
# Out:
#                                         Happiness Rank  Happiness Score
# Region                     Country
# Australia and New Zealand  Australia              10.0            7.284
#                            New Zealand             8.0            7.314
# Central and Eastern Europe Albania               109.0            4.644

# %%
df_drop_2018 = df_2018.drop(['GDP per capita',
       'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption'],axis=1)
# 2018 yilda tegishli datasetdagi no zarur ustunlarni uchirdek

# %%
df_drop_2018.rename(columns={'Overall rank':'Happiness Rank', 'Country or region':'Country', 'Score':'Happiness Score'}, inplace=True)
# ustunlardagi xato nomlarni o'zimizga kerakli nomga o'zgartirdek

# %%
df_irarxik_2018 =  pd.pivot_table(df_drop_2018, index = [df_region,'Country'],
                                  values = ['Happiness Rank','Happiness Score']) 
df_irarxik_2018.head(3)
# Avvalgi qismdagi Region ustunini shu datasetda mavjud bo'lmagan ustunlar ro'yxatiga qo'shdek
# irarxik indeksli ma'lumotlar to'plamiga o'tish 2018 yilga tegishli ma'lumotlar uchun
# Out:
#                                         Happiness Rank  Happiness Score
# Region                     Country
# Australia and New Zealand  Australia              10.0            7.272
#                            New Zealand             8.0            7.324
# Central and Eastern Europe Belarus                73.0            5.483

# %%
df_drop_2019 = df_2019.drop(['GDP per capita',
       'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption'],axis=1)

# %%
df_drop_2019.rename(columns={'Overall rank':'Happiness Rank', 'Country or region':'Country', 'Score':'Happiness Score'}, inplace=True)
# ustunlardagi xato nomlarni o'zimizga kerakli nomga o'zgartirdek

# %%
df_irarxik_2019 =  pd.pivot_table(df_drop_2019, index = [df_region,'Country'],
                                  values = ['Happiness Rank','Happiness Score']) 
df_irarxik_2019.head(3)
# Avvalgi qismdagi Region ustunini shu datasetda mavjud bo'lmagan ustunlar ro'yxatiga qo'shdek
# irarxik indeksli ma'lumotlar to'plamiga o'tish 2019 yilga tegishli ma'lumotlar uchun
# Out:
#                                         Happiness Rank  Happiness Score
# Region                     Country
# Australia and New Zealand  Austria                10.0            7.246
#                            New Zealand             8.0            7.307
# Central and Eastern Europe Argentina              47.0            6.086

# %%
df_drop_2020 = df_2020.drop(['Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
       'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption', 'Ladder score in Dystopia',
       'Explained by: Log GDP per capita', 'Explained by: Social support',
       'Explained by: Healthy life expectancy',
       'Explained by: Freedom to make life choices',
       'Explained by: Generosity', 'Explained by: Perceptions of corruption',
       'Dystopia + residual'],axis=1)

# %%
df_drop_2020.rename(columns={'Country name':'Country','Regional indicator':'Region','Ladder score':'Happiness Score'}, inplace=True)
# ustunlardagi xato nomlarni o'zimizga kerakli nomga o'zgartirdek

# %%
df_irarxik_2020 =  pd.pivot_table(df_drop_2020, index = ['Region','Country'],
                                  values = ['Happiness Score']) 
df_irarxik_2020.head(3)
# irarxik indeksli ma'lumotlar to'plamiga o'tish 2020 yilga tegishli ma'lumotlar uchun
# Out:
#                                                    Happiness Score
# Region                     Country
# Central and Eastern Europe Albania                          4.8827
#                            Bosnia and Herzegovina           5.6741
#                            Bulgaria                         5.1015

# %%
df_drop_2021 = df_2021.drop(['Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
       'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption', 'Ladder score in Dystopia',
       'Explained by: Log GDP per capita', 'Explained by: Social support',
       'Explained by: Healthy life expectancy',
       'Explained by: Freedom to make life choices',
       'Explained by: Generosity', 'Explained by: Perceptions of corruption',
       'Dystopia + residual'],axis=1)

# %%
df_drop_2021.rename(columns={'Country name':'Country','Regional indicator':'Region','Ladder score':'Happiness Score'},inplace=True)
# ustunlardagi xato nomlarni o'zimizga kerakli nomga o'zgartirdek

# %%
df_irarxik_2021 =  pd.pivot_table(df_drop_2021, index = ['Region','Country'],
                                  values = ['Happiness Score']) 
df_irarxik_2021.head(3)
# irarxik indeksli ma'lumotlar to'plamiga o'tish 2021 yilga tegishli ma'lumotlar uchun
# Out:
#                                                    Happiness Score
# Region                     Country
# Central and Eastern Europe Albania                           5.117
#                            Bosnia and Herzegovina            5.813
#                            Bulgaria                          5.266

# %%
df_drop_2019[df_drop_2019['Country']=='Albania']
# Out:
#      Happiness Rank  Country  Happiness Score                           Region
# 106             107  Albania            4.719  Middle East and Northern Africa

# %%
data_2015 = pd.DataFrame(df_irarxik_2015.values, index = df_irarxik_2015.index, columns= [['2015','2015'],['Happiness Rank','Happiness Score']])
data_2016 = pd.DataFrame(df_irarxik_2016.values, index =df_irarxik_2016.index, columns= [['2016','2016'],['Happiness Rank','Happiness Score']])
data_2017 = pd.DataFrame(df_irarxik_2017.values, index = df_irarxik_2017.index, columns= [['2017','2017'],['Happiness Rank','Happiness Score']])
data_2018 = pd.DataFrame(df_irarxik_2018.values, index =df_irarxik_2018.index, columns= [['2018','2018'],['Happiness Rank','Happiness Score']])
data_2019 = pd.DataFrame(df_irarxik_2019.values, index =df_irarxik_2019.index, columns= [['2019','2019'],['Happiness Rank','Happiness Score']])
data_2020 = pd.DataFrame(df_irarxik_2020.values, index = df_irarxik_2020.index, columns= [['2020'],['Happiness Score']])
data_2021 = pd.DataFrame(df_irarxik_2021.values, index =df_irarxik_2021.index, columns= [['2021'],['Happiness Score']])

# %%
df_concat = pd.concat([data_2015,data_2016,data_2017,data_2018,data_2019,data_2020,data_2021],axis=1)

# %%
df_concat.dropna(inplace=True)
df_concat
# Out:
#                                                  2015                  \
#                                        Happiness Rank Happiness Score
# Region                     Country
# Central and Eastern Europe Kosovo                69.0           5.589
# Sub-Saharan Africa         Ethiopia             122.0           4.512
#                            Guinea               150.0           3.656
#                            Madagascar           147.0           3.681
#                            Malawi               131.0           4.292
#                            Mali                 138.0           3.995
#                            Tanzania             146.0           3.781
#                            Uganda               141.0           3.931
# Western Europe             Belgium               19.0           6.937
#                            Denmark                3.0           7.527
#                            Finland                6.0           7.406
# ...

# %%
df_d2015 = df_drop_2015.drop(['Region'],axis=1)
df_d2016 = df_drop_2016.drop(['Region'],axis=1)
df_d2018 = df_drop_2018.drop(['Region'],axis=1)
df_d2019 = df_drop_2019.drop(['Region'],axis=1)
df_d2020 = df_drop_2020.drop(['Region'],axis=1)
df_d2021 = df_drop_2021.drop(['Region'],axis=1)

# %%
data_d2015 = pd.DataFrame(df_d2015.values, index = df_d2015.index, columns= [['2015','2015','2015'],['Country','Happiness Rank','Happiness Score']])
data_d2016 = pd.DataFrame(df_d2016.values, index =df_d2016.index, columns= [['2016','2016','2016'],['Country','Happiness Rank','Happiness Score']])
data_d2017 = pd.DataFrame(df_drop_2017.values, index = df_drop_2017.index, columns= [['2017','2017','2017'],['Country','Happiness Rank','Happiness Score']])
data_d2018 = pd.DataFrame(df_d2018.values, index =df_drop_2018.index, columns= [['2018','2018','2018'],['Country','Happiness Rank','Happiness Score']])
data_d2019 = pd.DataFrame(df_d2019.values, index =df_drop_2019.index, columns= [['2019','2019','2019'],['Country','Happiness Rank','Happiness Score']])
data_d2020 = pd.DataFrame(df_d2020.values, index = df_d2020.index, columns= [['2020','2020'],['Country','Happiness Score']])
data_d2021 = pd.DataFrame(df_d2021.values, index =df_d2021.index, columns= [['2021','2021'],['Country','Happiness Score']])

# %%
df_concat_2 = pd.concat([data_d2015,data_d2016,data_d2017,data_d2018,data_d2019,data_d2020,data_d2021],axis=1)

# %%
df_concat_2.dropna(inplace=True)
df_concat_2
# Out:
#                          2015                                         2016  \
#                       Country Happiness Rank Happiness Score       Country
# 0                 Switzerland              1           7.587       Denmark
# 1                     Iceland              2           7.561   Switzerland
# 2                     Denmark              3           7.527       Iceland
# 3                      Norway              4           7.522        Norway
# 4                      Canada              5           7.427       Finland
# ..                        ...            ...             ...           ...
# 144                  Cambodia            145           3.819  Burkina Faso
# 145                  Tanzania            146           3.781        Uganda
# 146                Madagascar            147           3.681         Yemen
# 147  Central African Republic            148           3.678    Madagascar
# ...
