# %% [markdown]
# <a href="https://colab.research.google.com/github/obidjonqunduzov/data-science/blob/main/3_5_Dataset_statistika.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/uzbekistan.csv', index_col=0)
df.columns = ['maydoni','aholisi']
df
# Out:
#                                 maydoni    aholisi
# Boʻlinishi
# Andijon viloyati                 4200.0  1899000.0
# Buxoro viloyati                 39400.0  1384700.0
# Fargʻona viloyati                6800.0  2597000.0
# Jizzax viloyati                 20500.0   910500.0
# Xorazm viloyati                  6300.0  1200000.0
# Namangan viloyati                7900.0  1862000.0
# Navoiy viloyati                110800.0   767500.0
# Qashqadaryo viloyati            28400.0  2029000.0
# Qoraqalpogʻiston Respublikasi  160000.0  1200000.0
# Samarqand viloyati              16400.0  2322000.0
# Sirdaryo viloyati                5100.0   648100.0
# Surxondaryo viloyati            20800.0  1676000.0
# Toshkent viloyati               15300.0  4450000.0

# %%
df.sum() # qator bo'yicha umumiy qiymatlari
# Out:
# maydoni      441900.0
# aholisi    22945800.0
# dtype: float64

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/gm_sales.csv", index_col=0)
df2
# Out:
#          2020   2021
# Labo     4521   7542
# Damas   30889  33682
# Spark   16370   6485
# Nexia   41663  14442
# Cobalt  44901  36317
# Gentra  30368  26266

# %%
df2.sum() # qator bo'yisha qiymatlari
# Out:
# 2020    168712
# 2021    124734
# dtype: int64

# %%
df2.sum(axis=1) # ustun bo'yicha qiymatlari
# Out:
# Labo      12063
# Damas     64571
# Spark     22855
# Nexia     56105
# Cobalt    81218
# Gentra    56634
# dtype: int64

# %%
df2.mean(axis=1) # ustun bo'yicha o'rtacha qiymatlari
# Out:
# Labo       6031.5
# Damas     32285.5
# Spark     11427.5
# Nexia     28052.5
# Cobalt    40609.0
# Gentra    28317.0
# dtype: float64

# %%
df
# Out:
#                                 maydoni    aholisi
# Boʻlinishi
# Andijon viloyati                 4200.0  1899000.0
# Buxoro viloyati                 39400.0  1384700.0
# Fargʻona viloyati                6800.0  2597000.0
# Jizzax viloyati                 20500.0   910500.0
# Xorazm viloyati                  6300.0  1200000.0
# Namangan viloyati                7900.0  1862000.0
# Navoiy viloyati                110800.0   767500.0
# Qashqadaryo viloyati            28400.0  2029000.0
# Qoraqalpogʻiston Respublikasi  160000.0  1200000.0
# Samarqand viloyati              16400.0  2322000.0
# Sirdaryo viloyati                5100.0   648100.0
# Surxondaryo viloyati            20800.0  1676000.0
# Toshkent viloyati               15300.0  4450000.0

# %%
df.idxmax() # df ro'yxatimizni maydoni va aholisi bo'yicha max qiymatlari
# Out:
# maydoni    Qoraqalpogʻiston Respublikasi
# aholisi                Toshkent viloyati
# dtype: object

# %%
df.idxmin() # df ro'yxatimizni maydoni va aholisi bo'yicha min qiymatlari
# Out:
# maydoni     Andijon viloyati
# aholisi    Sirdaryo viloyati
# dtype: object

# %%
df['aholisi'].argmax() # ro'yxatdagi aholisi eng ko'p viloyatning joylashgan index raqamini qaytaradi
# Out:
# 12

# %%
df.iloc[12] # demak bu Toshkent viloyati
# Out:
# maydoni      15300.0
# aholisi    4450000.0
# Name: Toshkent viloyati, dtype: float64

# %%
df['maydoni'].argmin() # maydoni bo'yicha eng kichik viloyat
# Out:
# 0

# %%
df.iloc[0]
# Out:
# maydoni       4200.0
# aholisi    1899000.0
# Name: Andijon viloyati, dtype: float64

# %%
df2.idxmax()
# Out:
# 2020    Cobalt
# 2021    Cobalt
# dtype: object

# %%
df2.idxmin()
# Out:
# 2020     Labo
# 2021    Spark
# dtype: object

# %% [markdown]
# Boshqa funksiyalar
# count - NaN bo'lmagan qiymatlar soni
#
# median - qiymatlar medianini hisbolash
#
# mad - mean absolute deviation
#
# prod - barcha qiymatlar ko'paytmasi
#
# var - variance (dispersiya)
#
# std - standart deviation (standart chetlanis)
#
# skew - skewness
#
# kurt - kurtosis
#
# cumsum - cumulative sum
#
# cummin va cummax- cumulative min and max
#
# cumprod - cumulative product
#
# diff - arifmetik farq (difference)
#
# pct_change - percent changes
