# %% [markdown]
# <a href="https://colab.research.google.com/github/obidjonqunduzov/data-science/blob/main/2_5_Data_Frame_Lu'gat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
from pandas import DataFrame

# %%
data = {
    'Uzbekistan':{2021:33.9, 2020:33.5, 2019:32.9, 2018:32.5, 2017:31.9},
    'Kazakhstan':{2021:18.9, 2020:18.7, 2019:18.5, 2018:18.3, 2017:18.1, 2016:17.8}
}

# %%
data_2 = pd.DataFrame(data) # lu'gat ichida lu'gat yaratamiz

# %%
data_2.index.name = 'Yil' # lu'gatning indexsiga nom beramiz

# %%
data_2
# Out:
#       Uzbekistan  Kazakhstan
# Yil
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %%
data_2 = pd.DataFrame(data, index = [2021,2020,2019]) # faqat o'zomizga kerakli qismini chaqirib olamiz

# %%
data_2
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5

# %%
data_2.T # indeks va ustunlar o'rnini almashtirish uchun
# Out:
#             2021  2020  2019
# Uzbekistan  33.9  33.5  32.9
# Kazakhstan  18.9  18.7  18.5

# %%
data_2.values
# Out:
# array([[33.9, 18.9],
#        [33.5, 18.7],
#        [32.9, 18.5]])

# %%
index = data_2.index
index
# Out:
# Int64Index([2021, 2020, 2019], dtype='int64')

# %%
usernames = {"anvar":"anvarbek223", "olim":"olimtoy", "maryam":"mary334455","javohir":"javohir445"}
emails = {"anvar":"anvar@gmail.com", "olim":"olim@mail.ru", "maryam":"mary33@gmail.com","javohir":"javohir445@gmail.com"}

data = {
    'username':usernames,
    'email':emails
}
df = pd.DataFrame(data)

# %%
df
# Out:
#             username                 email
# anvar    anvarbek223       anvar@gmail.com
# olim         olimtoy          olim@mail.ru
# maryam    mary334455      mary33@gmail.com
# javohir   javohir445  javohir445@gmail.com

# %%
data2 = {
    'username':{"olim":"olimjon21", "maryam":"maryam2020"},
    'email':{"olim":"olimjon21@mail.ru", "maryam":"maryam20@gmail.com"}
}

# %%
df2 = df.append(pd.DataFrame(data2))
df2
# Out:
# <ipython-input-23-aa695d280860>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df.append(pd.DataFrame(data2))
#             username                 email
# anvar    anvarbek223       anvar@gmail.com
# olim         olimtoy          olim@mail.ru
# maryam    mary334455      mary33@gmail.com
# javohir   javohir445  javohir445@gmail.com
# olim       olimjon21     olimjon21@mail.ru
# maryam    maryam2020    maryam20@gmail.com

# %%
df2.index
# Out:
# Index(['anvar', 'olim', 'maryam', 'javohir', 'olim', 'maryam'], dtype='object')

# %%
newind.isin(df2.index)
# Out:
# array([ True, False, False])

# %%
newind = pd.Index(['olim','nafisa','hamida']) # yangi indeks yaratamiz
newind
# Out:
# Index(['olim', 'nafisa', 'hamida'], dtype='object')

# %%
df2.index.difference(newind)
# Out:
# Index(['anvar', 'javohir', 'maryam'], dtype='object')
