# %% [markdown]
# <a href="https://colab.research.google.com/github/obidjonqunduzov/data-science/blob/main/2_3_Data_Frame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data_user_russia = {
    'year':[1990, 1995, 2000, 2005, 2010, 2015, 2020, 2023],
    'born':[147665081, 1363806,1266800,	1457376, 1788948, 1940579, 1436514, 1398253],
    'temp':[1.892, 1.337, 1.195, 1.294, 1.567, 1.777, 1.579, 1.504]
}

# %%
data_info = pd.DataFrame(data_user_russia)
data_info
# Out:
#    year       born   temp
# 0  1990  147665081  1.892
# 1  1995    1363806  1.337
# 2  2000    1266800  1.195
# 3  2005    1457376  1.294
# 4  2010    1788948  1.567
# 5  2015    1940579  1.777
# 6  2020    1436514  1.579
# 7  2023    1398253  1.504
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# data_info['year'].plot(kind='hist', bins=20, title='year')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# data_info['born'].plot(kind='hist', bins=20, title='born')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# data_info['temp'].plot(kind='hist', bins=20, title='temp')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
# ...

# %%
data_info.head() # agar ma'lumotlarimiz juda ko'p  bo'lsa shu usuldan foydalanib o'zimizga kerakli qismini olamiz
# Out:
#    year       born   temp
# 0  1990  147665081  1.892
# 1  1995    1363806  1.337
# 2  2000    1266800  1.195
# 3  2005    1457376  1.294
# 4  2010    1788948  1.567
