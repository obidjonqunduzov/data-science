# %% [markdown]
# <a href="https://colab.research.google.com/github/obidjonqunduzov/data-science/blob/main/4_2_web_fayllar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# Khudjand shahri haqida ma'lumot
khudjand_data = pd.read_html("https://ru.wikipedia.org/wiki/%D0%A5%D1%83%D0%B4%D0%B6%D0%B0%D0%BD%D0%B4")

# %%
len(khudjand_data) # Bu khujand_data ichida 9 ta data(ma'lumotlar to'plami) bor ekan
# Out:
# 9

# %%
khudjand_data[3] # shu datamizni 3chisi nimaligini ko'rsatadi
# Out:
#   Численность населения[13]                                                    \
#                        1897      1926      1959      1973      1989      1992
# 0                    30 000   ↗37 000   ↗77 000  ↗113 000  ↗160 000  ↗165 300
# 1                  2004[14]  2005[14]  2006[14]  2007[14]  2008[14]  2009[14]
# 2                  ↗151 700  ↗153 100  ↗154 700  ↗155 900  ↗157 100  ↗158 200
# 3                      2012      2013      2014      2015      2016      2017
# 4                  ↗165 400  ↗167 400  ↗169 700  ↗172 700  ↗175 400  ↗178 100
# 5                  2020[16]  2021[17]  2022[17]       NaN       NaN       NaN
# 6                  ↗183 600  ↗196 800  ↗198 700       NaN       NaN       NaN
#
#
#        2002  2003[14]
# 0  ↘147 000  ↗150 500
# 1      2010      2011
# 2  ↗163 000  ↗165 000
# 3      2018  2019[15]
# 4  ↗179 900  ↗181 600
# 5       NaN       NaN
# 6       NaN       NaN

# %%
# J.Rasulov rayoni haqidagi ma'lumotlar
j_rasulov = pd.read_html("https://ru.wikipedia.org/wiki/%D0%94%D0%B6%D0%B0%D0%B1%D0%B1%D0%B0%D1%80-%D0%A0%D0%B0%D1%81%D1%83%D0%BB%D0%BE%D0%B2%D1%81%D0%BA%D0%B8%D0%B9_%D1%80%D0%B0%D0%B9%D0%BE%D0%BD")

# %%
len(j_rasulov)
# Out:
# 5

# %%
j_rasulov[1]
# Out:
#   Численность населения[4]                                                    \
#                    1939[5]   2003[6]   2004[6]   2005[6]   2006[6]   2007[6]
# 0                   21 468  ↗103 200  ↗105 000  ↗106 800  ↗108 800  ↗111 000
# 1                  2015[7]   2019[8]   2020[9]   2021[1]   2022[1]       NaN
# 2                 ↗125 000  ↗135 300  ↗137 700  ↗142 000   ↗144100       NaN
#
#
#     2008[6]   2009[6]
# 0  ↗113 200  ↗115 600
# 1       NaN       NaN
# 2       NaN       NaN

# %%
# Rossiyaning oxirgi 10 yillikdagi insonlarning demografiyasi
ros_data = pd.read_html("https://ru.wikipedia.org/wiki/%D0%9D%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5_%D0%A0%D0%BE%D1%81%D1%81%D0%B8%D0%B8")

# %%
len(ros_data) # 24 ta DataFrame bor ekan!
# Out:
# 24

# %%
ros_data[4] # bu oxirgi 8 yildagi demografiya keltirilgan
# Out:
#     Год Родилось, чел. Умерло, чел.  \
# 0  2011      1 796 629    1 925 720
# 1  2012      1 902 084    1 906 335
# 2  2013      1 895 822    1 871 809
# 3  2014      1 942 683    1 912 347
# 4  2015      1 940 579    1 908 541
# 5  2016      1 893 256    1 887 913
# 6  2017      1 689 884    1 824 340
# 7  2018      1 604 344    1 828 910
# 8  2019      1 481 074    1 798 307
#
#   Естественный прирост (+) или убыль (−), чел. Миграционный прирост, чел.  \
# 0                                     −129 091                    320 100
# 1                                       −4 251                    294 930
# 2                                       24 013                    231 061
# 3                                       30 336                    216 900
# 4                                       32 038                    219 748
# 5                                        5 343                    261 948
# 6                                     −134 456                    211 880
# ...
