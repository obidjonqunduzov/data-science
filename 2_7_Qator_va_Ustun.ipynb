# %% [markdown]
# <a href="https://colab.research.google.com/github/obidjonqunduzov/data-science/blob/main/2_7_Qator_va_Ustun.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from pandas import DataFrame

# %%
data = {
    'Yil':[2023, 2022, 2021, 2020, 2015, 2010],
    'Aholi soni':[8.5, 8.2, 8, 7.8, 7.2, 7],
    'Temp':[2.4, 2.2, 2.0, 1.85, 1.56, 1.45],
    'Zichlik':[65.4, 62.4, 58.75, 52.23, 48.95, 37.85]
}
dataframe = pd.DataFrame(data)

# %%
dataframe
# Out:
#     Yil  Aholi soni  Temp  Zichlik
# 0  2023         8.5  2.40    65.40
# 1  2022         8.2  2.20    62.40
# 2  2021         8.0  2.00    58.75
# 3  2020         7.8  1.85    52.23
# 4  2015         7.2  1.56    48.95
# 5  2010         7.0  1.45    37.85

# %%
dataframe.index=[23,22,21,20,15,10]
dataframe
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 23  2023         8.5  2.40    65.40
# 22  2022         8.2  2.20    62.40
# 21  2021         8.0  2.00    58.75
# 20  2020         7.8  1.85    52.23
# 15  2015         7.2  1.56    48.95
# 10  2010         7.0  1.45    37.85

# %%
df_2 = dataframe.drop([21,15,10]) # drop funksiyasi qatorlarni tashlab yuborishda ishlatiladi
df_2
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 23  2023         8.5  2.40    65.40
# 22  2022         8.2  2.20    62.40
# 20  2020         7.8  1.85    52.23

# %%
df_2 = dataframe.drop('Yil', axis=1) # drop funksiyasi bu erda Yil ustunini olib tashladi
df_2
# Out:
#     Aholi soni  Temp  Zichlik
# 23         8.5  2.40    65.40
# 22         8.2  2.20    62.40
# 21         8.0  2.00    58.75
# 20         7.8  1.85    52.23
# 15         7.2  1.56    48.95
# 10         7.0  1.45    37.85

# %%
dataframe
# Out:
#     Aholi soni  Temp  Zichlik
# 23         8.5  2.40    65.40
# 22         8.2  2.20    62.40
# 21         8.0  2.00    58.75
# 20         7.8  1.85    52.23
# 15         7.2  1.56    48.95
# 10         7.0  1.45    37.85
